# %% [markdown]
# # Calculate MassBank Coverage for KEGG MINE 2.0
# For Table 2, KEGG 2.0 coverage column

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import pymongo

from minedatabase.metabolomics import ms_adduct_search

# %% [markdown]
# ### Read Credentials for MongoDB

# %%
with open('./../credentials.txt', 'r') as infile:
    lines = infile.readlines()
    username = lines[0].strip().split('=')[1]
    password = lines[1].strip().split('=')[1]

# %% [markdown]
# ### Connect to MongoDB KEGG 2.0 MINE

# %%
uri = f'mongodb://{username}:{password}@minedatabase.ci.northwestern.edu:27017'
data_dir = './data'

client = pymongo.MongoClient(uri, ServerSelectionTimeoutMS=10000)
db = client['kegg_lte600_500mcy_2_1_0']
core_db = client['core']
kegg_models_db = client['kegg']

# %%
db.compounds.find_one('C000000588c5adcceec7bc0033b2404db527f006f')
# Out:
# {'_id': 'C000000588c5adcceec7bc0033b2404db527f006f',
#  'SMILES': 'CC(=O)N1CC2OC(O)C1C(O)C2OC1OC(CO)C(O)C(OC2OC(CO)C(O)C(O)C2O)C1O',
#  'InChI_key': 'ANMDONBJHHLQDM-UHFFFAOYSA-N',
#  'Type': 'Predicted',
#  'Generation': 1,
#  'Expand': True,
#  'Reactant_in': [],
#  'Product_of': ['C000000588c5adcceec7bc0033b2404db527f006f_0']}

# %% [markdown]
# ### Read MassBank Test Data File

# %%
massbank_filepath = './../Data/MassBankTestSet.csv'

mb_df = pd.read_csv(massbank_filepath, delimiter='\t', names=['Name', 'Charge', 'Mass', 'Mode', 'None', 'Adduct', 'InChI_Key'])
mb_df = mb_df.drop(['None'], axis=1)

# %%
mb_df.head()
# Out:
#                         Name  Charge      Mass      Mode  Adduct  \
# 0        Metamitron-desamino       0  188.0818  Positive  [M+H]+
# 1         4-Isopropylaniline       0  136.1121  Positive  [M+H]+
# 2   Metolachlor morpholinone       0  234.1489  Positive  [M+H]+
# 3      2,6-Dichlorobenzamide       0  189.9821  Positive  [M+H]+
# 4                    Amitraz       0  294.1965  Positive  [M+H]+
#
#                      InChI_Key
# 0  OUSYWCQYMPDAEO-UHFFFAOYSA-N
# 1  LRTFPLFDLJYEKT-UHFFFAOYSA-N
# 2  DVBDYPDVNRJKNJ-UHFFFAOYSA-N
# 3  JHSPCUHPSIUQRB-UHFFFAOYSA-N
# 4  QXAITBQSYVNQDR-UHFFFAOYSA-N

# %%
mb_df.tail()
# Out:
#                                       Name  Charge      Mass      Mode  \
# 662              Robinetin trimethyl ether       0  345.0969  Positive
# 663   3-Hydroxy-3',4',5'-trimethoxyflavone       0  329.1020  Positive
# 664              Carbobenzoxy-L-asparagine       0  265.0830  Negative
# 665                  (S)-(-)-Perillic acid       0  165.0921  Negative
# 666                            Kaempferide       0  299.0561  Negative
#
#      Adduct                    InChI_Key
# 662  [M+H]+  NJNGYVOYOVPWBB-UHFFFAOYSA-N
# 663  [M+H]+  MWFLTXAQDCOKEK-UHFFFAOYSA-N
# 664  [M-H]-  FUCKRCGERFLLHP-SECBINFHSA-N
# 665  [M-H]-  CDSMSBUVCWHORP-MRVPVSSYSA-N
# 666  [M-H]-  SQFSKOYWJBQGKQ-UHFFFAOYSA-N

# %%
mb_df = mb_df.loc[mb_df.Mass <= 600]

# %%
len(mb_df)
# Out:
# 634

# %% [markdown]
# ### Search KEGG 2.0 MINE for Masses in MassBank Test Data File
#
# Positive First

# %%
ms_params = {
    'adducts': ["[M+]+", "[M+H]+", "[M+Na]+"],
    'tolerance': 2,  # mDa
    'ppm': False,
    'logp': None,
    'halogens': True,
    'verbose': False,
    'charge': '+',
    'models': []
}

# %%
ids = mb_df.loc[mb_df.Mode == 'Positive'].index
masses = [str(val) for val in mb_df.loc[mb_df.Mode == 'Positive'].Mass.values]
len(masses)
# Out:
# 587

# %%
hits_dict = {}
for cpd_id, mass in zip(ids, masses):
    hits_dict[cpd_id] = ms_adduct_search(db=db, core_db=core_db, keggdb=kegg_models_db, text=mass, text_type='form', ms_params=ms_params)
    print(cpd_id, mass, len(hits_dict[cpd_id]))
# Out:
# <MS Adduct Search: TextType=form, Text=188.0818, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 0 188.0818 15
# <MS Adduct Search: TextType=form, Text=136.1121, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 1 136.1121 55
# <MS Adduct Search: TextType=form, Text=234.1489, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 2 234.1489 353
# <MS Adduct Search: TextType=form, Text=189.9821, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 3 189.9821 15
# <MS Adduct Search: TextType=form, Text=294.1965, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 4 294.1965 108
# <MS Adduct Search: TextType=form, Text=257.0478, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 5 257.0478 101
# <MS Adduct Search: TextType=form, Text=336.1166, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 6 336.1166 183
# <MS Adduct Search: TextType=form, Text=141.0771, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 7 141.0771 15
# <MS Adduct Search: TextType=form, Text=216.0325, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 8 216.0325 131
# <MS Adduct Search: TextType=form, Text=382.0816, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 9 382.0816 253
# <MS Adduct Search: TextType=form, Text=411.1081, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 10 411.1081 1142
# <MS Adduct Search: TextType=form, Text=432.0642, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 11 432.0642 86
# <MS Adduct Search: TextType=form, Text=134.0713, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 12 134.0713 5
# <MS Adduct Search: TextType=form, Text=322.0777, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 13 322.0777 298
# <MS Adduct Search: TextType=form, Text=214.1121, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 14 214.1121 24
# <MS Adduct Search: TextType=form, Text=174.0541, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 15 174.0541 715
# <MS Adduct Search: TextType=form, Text=219.0086, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 16 219.0086 72
# <MS Adduct Search: TextType=form, Text=201.0692, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 17 201.0692 79
# <MS Adduct Search: TextType=form, Text=193.1335, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 18 193.1335 127
# <MS Adduct Search: TextType=form, Text=188.0697, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 19 188.0697 865
# <MS Adduct Search: TextType=form, Text=215.0703, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 20 215.0703 911
# <MS Adduct Search: TextType=form, Text=215.0849, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 21 215.0849 64
# <MS Adduct Search: TextType=form, Text=125.0379, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 22 125.0379 31
# <MS Adduct Search: TextType=form, Text=330.137, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 23 330.137 67
# <MS Adduct Search: TextType=form, Text=208.0968, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 24 208.0968 664
# <MS Adduct Search: TextType=form, Text=226.1662, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 25 226.1662 57
# <MS Adduct Search: TextType=form, Text=230.1167, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 26 230.1167 684
# <MS Adduct Search: TextType=form, Text=202.0854, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 27 202.0854 858
# <MS Adduct Search: TextType=form, Text=274.1186, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 28 274.1186 187
# <MS Adduct Search: TextType=form, Text=302.1057, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 29 302.1057 96
# <MS Adduct Search: TextType=form, Text=153.1022, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 30 153.1022 102
# <MS Adduct Search: TextType=form, Text=230.1167, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 31 230.1167 684
# <MS Adduct Search: TextType=form, Text=166.1226, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 32 166.1226 362
# <MS Adduct Search: TextType=form, Text=241.0963, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 33 241.0963 692
# <MS Adduct Search: TextType=form, Text=453.1187, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 34 453.1187 575
# <MS Adduct Search: TextType=form, Text=482.1756, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 35 482.1756 318
# <MS Adduct Search: TextType=form, Text=240.115, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 36 240.115 234
# <MS Adduct Search: TextType=form, Text=441.167, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 37 441.167 528
# <MS Adduct Search: TextType=form, Text=515.2442, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 38 515.2442 495
# <MS Adduct Search: TextType=form, Text=559.2603, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 39 559.2603 450
# <MS Adduct Search: TextType=form, Text=304.1543, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 40 304.1543 1875
# <MS Adduct Search: TextType=form, Text=197.084, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 41 197.084 65
# <MS Adduct Search: TextType=form, Text=231.1104, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 42 231.1104 365
# <MS Adduct Search: TextType=form, Text=177.1386, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 43 177.1386 62
# <MS Adduct Search: TextType=form, Text=278.1903, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 44 278.1903 394
# <MS Adduct Search: TextType=form, Text=136.1121, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 45 136.1121 55
# <MS Adduct Search: TextType=form, Text=290.1387, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 46 290.1387 1510
# <MS Adduct Search: TextType=form, Text=272.2009, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 47 272.2009 594
# <MS Adduct Search: TextType=form, Text=278.1903, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 48 278.1903 394
# <MS Adduct Search: TextType=form, Text=238.0993, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 49 238.0993 179
# <MS Adduct Search: TextType=form, Text=178.1226, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 50 178.1226 269
# <MS Adduct Search: TextType=form, Text=310.2165, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 51 310.2165 273
# <MS Adduct Search: TextType=form, Text=150.1277, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 52 150.1277 124
# <MS Adduct Search: TextType=form, Text=327.1371, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 53 327.1371 460
# <MS Adduct Search: TextType=form, Text=256.1696, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 54 256.1696 99
# <MS Adduct Search: TextType=form, Text=240.1594, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 55 240.1594 546
# <MS Adduct Search: TextType=form, Text=370.1795, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 56 370.1795 160
# <MS Adduct Search: TextType=form, Text=308.0507, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 57 308.0507 250
# <MS Adduct Search: TextType=form, Text=557.3044, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 58 557.3044 38
# <MS Adduct Search: TextType=form, Text=205.0794, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 59 205.0794 87
# <MS Adduct Search: TextType=form, Text=295.2169, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 60 295.2169 103
# <MS Adduct Search: TextType=form, Text=330.1096, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 61 330.1096 498
# <MS Adduct Search: TextType=form, Text=408.1254, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 62 408.1254 133
# <MS Adduct Search: TextType=form, Text=358.20129, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 64 358.20129 971
# <MS Adduct Search: TextType=form, Text=271.0601, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 65 271.0601 2064
# <MS Adduct Search: TextType=form, Text=138.09134, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 66 138.09134 190
# <MS Adduct Search: TextType=form, Text=353.08672, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 67 353.08672 890
# <MS Adduct Search: TextType=form, Text=295.18049, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 68 295.18049 1628
# <MS Adduct Search: TextType=form, Text=368.11287, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 69 368.11287 511
# <MS Adduct Search: TextType=form, Text=268.13321, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 70 268.13321 857
# <MS Adduct Search: TextType=form, Text=166.08626, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 71 166.08626 581
# <MS Adduct Search: TextType=form, Text=539.09728, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 72 539.09728 557
# <MS Adduct Search: TextType=form, Text=285.07576, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 73 285.07576 2110
# <MS Adduct Search: TextType=form, Text=310.16545, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 74 310.16545 575
# <MS Adduct Search: TextType=form, Text=275.13902, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 76 275.13902 322
# <MS Adduct Search: TextType=form, Text=180.10191, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 77 180.10191 553
# <MS Adduct Search: TextType=form, Text=437.14423, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 78 437.14423 1166
# <MS Adduct Search: TextType=form, Text=481.30609, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 79 481.30609 993
# <MS Adduct Search: TextType=form, Text=153.05462, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 80 153.05462 635
# <MS Adduct Search: TextType=form, Text=183.09168, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 81 183.09168 67
# <MS Adduct Search: TextType=form, Text=291.08632, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 82 291.08632 1952
# <MS Adduct Search: TextType=form, Text=229.08592, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 83 229.08592 918
# <MS Adduct Search: TextType=form, Text=239.09141, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 84 239.09141 616
# <MS Adduct Search: TextType=form, Text=288.12303, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 85 288.12303 1893
# <MS Adduct Search: TextType=form, Text=355.154, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 86 355.154 1588
# <MS Adduct Search: TextType=form, Text=336.12358, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 87 336.12358 234
# <MS Adduct Search: TextType=form, Text=395.14892, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 88 395.14892 1026
# <MS Adduct Search: TextType=form, Text=216.08799, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 89 216.08799 429
# <MS Adduct Search: TextType=form, Text=162.05496, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 90 162.05496 222
# <MS Adduct Search: TextType=form, Text=354.1336, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 91 354.1336 1121
# <MS Adduct Search: TextType=form, Text=268.10404, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 93 268.10404 800
# <MS Adduct Search: TextType=form, Text=579.17084, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 95 579.17084 4852
# <MS Adduct Search: TextType=form, Text=217.04954, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 96 217.04954 396
# <MS Adduct Search: TextType=form, Text=414.15473, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 97 414.15473 522
# <MS Adduct Search: TextType=form, Text=303.04993, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 98 303.04993 1386
# <MS Adduct Search: TextType=form, Text=287.05502, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 99 287.05502 1575
# <MS Adduct Search: TextType=form, Text=205.09716, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 100 205.09716 573
# <MS Adduct Search: TextType=form, Text=581.18649, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 102 581.18649 3536
# <MS Adduct Search: TextType=form, Text=315.16097, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 103 315.16097 2048
# <MS Adduct Search: TextType=form, Text=514.21438, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 104 514.21438 935
# <MS Adduct Search: TextType=form, Text=182.08117, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 105 182.08117 666
# <MS Adduct Search: TextType=form, Text=183.08632, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 106 183.08632 138
# <MS Adduct Search: TextType=form, Text=220.11929, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 107 220.11929 340
# <MS Adduct Search: TextType=form, Text=183.08632, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 108 183.08632 138
# <MS Adduct Search: TextType=form, Text=382.17212, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 109 382.17212 675
# <MS Adduct Search: TextType=form, Text=175.11896, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 111 175.11896 36
# <MS Adduct Search: TextType=form, Text=166.08626, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 112 166.08626 581
# <MS Adduct Search: TextType=form, Text=181.07067, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 113 181.07067 520
# <MS Adduct Search: TextType=form, Text=204.12438, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 114 204.12438 358
# <MS Adduct Search: TextType=form, Text=300.28971, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 116 300.28971 743
# <MS Adduct Search: TextType=form, Text=187.0577, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 119 187.0577 514
# <MS Adduct Search: TextType=form, Text=150.05833, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 122 150.05833 112
# <MS Adduct Search: TextType=form, Text=382.17212, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 124 382.17212 675
# <MS Adduct Search: TextType=form, Text=106.04987, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 125 106.04987 68
# <MS Adduct Search: TextType=form, Text=352.16155, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 126 352.16155 742
# <MS Adduct Search: TextType=form, Text=365.10544, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 127 365.10544 3759
# <MS Adduct Search: TextType=form, Text=118.08626, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 128 118.08626 252
# <MS Adduct Search: TextType=form, Text=241.03113, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 129 241.03113 731
# <MS Adduct Search: TextType=form, Text=382.17212, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 132 382.17212 675
# <MS Adduct Search: TextType=form, Text=132.10191, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 133 132.10191 236
# <MS Adduct Search: TextType=form, Text=116.07061, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 134 116.07061 263
# <MS Adduct Search: TextType=form, Text=365.10544, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 135 365.10544 3759
# <MS Adduct Search: TextType=form, Text=148.06044, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 137 148.06044 497
# <MS Adduct Search: TextType=form, Text=132.10191, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 138 132.10191 236
# <MS Adduct Search: TextType=form, Text=198.09722, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 139 198.09722 75
# <MS Adduct Search: TextType=form, Text=343.1235, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 140 343.1235 3961
# <MS Adduct Search: TextType=form, Text=382.17212, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 141 382.17212 675
# <MS Adduct Search: TextType=form, Text=181.076, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 142 181.076 33
# <MS Adduct Search: TextType=form, Text=180.0808, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 143 180.0808 14
# <MS Adduct Search: TextType=form, Text=114.0105, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 144 114.0105 3
# <MS Adduct Search: TextType=form, Text=82.0651, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 145 82.0651 44
# <MS Adduct Search: TextType=form, Text=122.0964, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 146 122.0964 41
# <MS Adduct Search: TextType=form, Text=136.1121, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 147 136.1121 55
# <MS Adduct Search: TextType=form, Text=130.0651, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 148 130.0651 10
# <MS Adduct Search: TextType=form, Text=138.0105, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 149 138.0105 6
# <MS Adduct Search: TextType=form, Text=119.0604, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 150 119.0604 17
# <MS Adduct Search: TextType=form, Text=119.0604, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 151 119.0604 17
# <MS Adduct Search: TextType=form, Text=102.1277, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 152 102.1277 28
# <MS Adduct Search: TextType=form, Text=129.0214, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 153 129.0214 3
# <MS Adduct Search: TextType=form, Text=289.1215, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 154 289.1215 1602
# <MS Adduct Search: TextType=form, Text=154.0651, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 155 154.0651 21
# <MS Adduct Search: TextType=form, Text=119.0604, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 156 119.0604 17
# <MS Adduct Search: TextType=form, Text=132.0808, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 157 132.0808 41
# <MS Adduct Search: TextType=form, Text=181.076, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 158 181.076 33
# <MS Adduct Search: TextType=form, Text=170.0964, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 159 170.0964 54
# <MS Adduct Search: TextType=form, Text=220.9532, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 160 220.9532 26
# <MS Adduct Search: TextType=form, Text=318.013, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 161 318.013 90
# <MS Adduct Search: TextType=form, Text=230.0069, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 162 230.0069 71
# <MS Adduct Search: TextType=form, Text=233.0243, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 163 233.0243 83
# <MS Adduct Search: TextType=form, Text=207.1492, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 164 207.1492 247
# <MS Adduct Search: TextType=form, Text=305.1083, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 165 305.1083 271
# <MS Adduct Search: TextType=form, Text=213.0789, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 166 213.0789 86
# <MS Adduct Search: TextType=form, Text=297.0556, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 167 297.0556 187
# <MS Adduct Search: TextType=form, Text=395.0813, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 168 395.0813 480
# <MS Adduct Search: TextType=form, Text=316.1076, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 169 316.1076 175
# <MS Adduct Search: TextType=form, Text=409.137, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 170 409.137 1501
# <MS Adduct Search: TextType=form, Text=329.0245, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 171 329.0245 204
# <MS Adduct Search: TextType=form, Text=399.0969, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 172 399.0969 426
# <MS Adduct Search: TextType=form, Text=202.0433, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 173 202.0433 20
# <MS Adduct Search: TextType=form, Text=287.0948, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 174 287.0948 324
# <MS Adduct Search: TextType=form, Text=203.0927, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 175 203.0927 356
# <MS Adduct Search: TextType=form, Text=222.0429, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 176 222.0429 90
# <MS Adduct Search: TextType=form, Text=298.2741, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 177 298.2741 1023
# <MS Adduct Search: TextType=form, Text=374.0934, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 178 374.0934 111
# <MS Adduct Search: TextType=form, Text=214.1121, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 179 214.1121 24
# <MS Adduct Search: TextType=form, Text=404.1241, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 180 404.1241 297
# <MS Adduct Search: TextType=form, Text=304.2635, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 181 304.2635 229
# <MS Adduct Search: TextType=form, Text=384.9949, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 182 384.9949 87
# <MS Adduct Search: TextType=form, Text=306.1036, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 183 306.1036 79
# <MS Adduct Search: TextType=form, Text=249.0192, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 184 249.0192 140
# <MS Adduct Search: TextType=form, Text=230.1167, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 185 230.1167 684
# <MS Adduct Search: TextType=form, Text=216.101, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 186 216.101 831
# <MS Adduct Search: TextType=form, Text=254.1434, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 187 254.1434 41
# <MS Adduct Search: TextType=form, Text=342.0771, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 188 342.0771 228
# <MS Adduct Search: TextType=form, Text=278.1055, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 189 278.1055 121
# <MS Adduct Search: TextType=form, Text=242.1434, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 190 242.1434 28
# <MS Adduct Search: TextType=form, Text=358.9768, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 191 358.9768 46
# <MS Adduct Search: TextType=form, Text=239.1503, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 192 239.1503 67
# <MS Adduct Search: TextType=form, Text=284.1412, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 193 284.1412 826
# <MS Adduct Search: TextType=form, Text=202.0854, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 194 202.0854 858
# <MS Adduct Search: TextType=form, Text=309.1121, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 195 309.1121 536
# <MS Adduct Search: TextType=form, Text=308.1524, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 196 308.1524 81
# <MS Adduct Search: TextType=form, Text=253.0309, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 197 253.0309 357
# <MS Adduct Search: TextType=form, Text=165.1022, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 198 165.1022 108
# <MS Adduct Search: TextType=form, Text=291.0895, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 199 291.0895 96
# <MS Adduct Search: TextType=form, Text=235.1441, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 200 235.1441 414
# <MS Adduct Search: TextType=form, Text=228.1277, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 201 228.1277 23
# <MS Adduct Search: TextType=form, Text=192.0768, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 202 192.0768 104
# <MS Adduct Search: TextType=form, Text=204.993, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 203 204.993 23
# <MS Adduct Search: TextType=form, Text=308.004, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 204 308.004 105
# <MS Adduct Search: TextType=form, Text=240.0786, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 205 240.0786 146
# <MS Adduct Search: TextType=form, Text=226.0896, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 206 226.0896 70
# <MS Adduct Search: TextType=form, Text=376.0381, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 207 376.0381 193
# <MS Adduct Search: TextType=form, Text=282.1448, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 208 282.1448 576
# <MS Adduct Search: TextType=form, Text=343.0399, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 209 343.0399 185
# <MS Adduct Search: TextType=form, Text=312.0665, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 210 312.0665 177
# <MS Adduct Search: TextType=form, Text=296.1412, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 211 296.1412 239
# <MS Adduct Search: TextType=form, Text=252.1417, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 212 252.1417 60
# <MS Adduct Search: TextType=form, Text=334.1049, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 213 334.1049 870
# <MS Adduct Search: TextType=form, Text=377.0908, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 214 377.0908 304
# <MS Adduct Search: TextType=form, Text=231.1016, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 215 231.1016 880
# <MS Adduct Search: TextType=form, Text=332.1405, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 216 332.1405 294
# <MS Adduct Search: TextType=form, Text=189.1022, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 217 189.1022 310
# <MS Adduct Search: TextType=form, Text=362.1154, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 218 362.1154 242
# <MS Adduct Search: TextType=form, Text=231.1492, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 219 231.1492 328
# <MS Adduct Search: TextType=form, Text=268.1907, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 220 268.1907 274
# <MS Adduct Search: TextType=form, Text=323.0196, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 221 323.0196 124
# <MS Adduct Search: TextType=form, Text=362.1511, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 223 362.1511 193
# ...
# 581 227.1027 900
# <MS Adduct Search: TextType=form, Text=177.0546, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 582 177.0546 420
# <MS Adduct Search: TextType=form, Text=267.1492, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 583 267.1492 303
# <MS Adduct Search: TextType=form, Text=408.2507, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 584 408.2507 1626
# <MS Adduct Search: TextType=form, Text=267.0419, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 585 267.0419 256
# <MS Adduct Search: TextType=form, Text=513.1028, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 586 513.1028 162
# <MS Adduct Search: TextType=form, Text=299.0914, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 587 299.0914 1208
# <MS Adduct Search: TextType=form, Text=258.1085, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 589 258.1085 653
# <MS Adduct Search: TextType=form, Text=300.0761, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 590 300.0761 98
# <MS Adduct Search: TextType=form, Text=308.1354, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 591 308.1354 433
# <MS Adduct Search: TextType=form, Text=324.1667, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 592 324.1667 254
# <MS Adduct Search: TextType=form, Text=243.1088, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 594 243.1088 436
# <MS Adduct Search: TextType=form, Text=256.1292, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 595 256.1292 483
# <MS Adduct Search: TextType=form, Text=236.1142, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 596 236.1142 236
# <MS Adduct Search: TextType=form, Text=378.0058, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 597 378.0058 17
# <MS Adduct Search: TextType=form, Text=319.0247, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 598 319.0247 239
# <MS Adduct Search: TextType=form, Text=257.0809, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 599 257.0809 1970
# <MS Adduct Search: TextType=form, Text=255.0652, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 600 255.0652 1692
# <MS Adduct Search: TextType=form, Text=279.0419, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 601 279.0419 214
# <MS Adduct Search: TextType=form, Text=221.0809, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 602 221.0809 659
# <MS Adduct Search: TextType=form, Text=255.1016, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 603 255.1016 1047
# <MS Adduct Search: TextType=form, Text=269.0809, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 604 269.0809 1142
# <MS Adduct Search: TextType=form, Text=285.1122, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 605 285.1122 892
# <MS Adduct Search: TextType=form, Text=251.1067, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 606 251.1067 329
# <MS Adduct Search: TextType=form, Text=339.1591, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 607 339.1591 789
# <MS Adduct Search: TextType=form, Text=142.0975, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 608 142.0975 83
# <MS Adduct Search: TextType=form, Text=223.0878, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 609 223.0878 43
# <MS Adduct Search: TextType=form, Text=501.1603, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 610 501.1603 546
# <MS Adduct Search: TextType=form, Text=543.1709, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 612 543.1709 281
# <MS Adduct Search: TextType=form, Text=345.1268, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 613 345.1268 1184
# <MS Adduct Search: TextType=form, Text=273.1234, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 614 273.1234 572
# <MS Adduct Search: TextType=form, Text=301.0626, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 615 301.0626 278
# <MS Adduct Search: TextType=form, Text=299.0914, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 616 299.0914 1208
# <MS Adduct Search: TextType=form, Text=285.0677, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 617 285.0677 142
# <MS Adduct Search: TextType=form, Text=315.0015, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 618 315.0015 245
# <MS Adduct Search: TextType=form, Text=447.1286, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 619 447.1286 3365
# <MS Adduct Search: TextType=form, Text=347.0762, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 622 347.0762 1833
# <MS Adduct Search: TextType=form, Text=301.0707, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 623 301.0707 2121
# <MS Adduct Search: TextType=form, Text=531.1497, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 624 531.1497 802
# <MS Adduct Search: TextType=form, Text=365.102, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 625 365.102 511
# <MS Adduct Search: TextType=form, Text=170.0118, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 628 170.0118 47
# <MS Adduct Search: TextType=form, Text=179.0339, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 629 179.0339 326
# <MS Adduct Search: TextType=form, Text=216.1019, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 630 216.1019 222
# <MS Adduct Search: TextType=form, Text=419.1337, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 631 419.1337 2383
# <MS Adduct Search: TextType=form, Text=315.0863, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 633 315.0863 1849
# <MS Adduct Search: TextType=form, Text=483.1906, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 634 483.1906 1591
# <MS Adduct Search: TextType=form, Text=286.1438, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 636 286.1438 2341
# <MS Adduct Search: TextType=form, Text=299.0914, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 637 299.0914 1208
# <MS Adduct Search: TextType=form, Text=197.0669, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 638 197.0669 596
# <MS Adduct Search: TextType=form, Text=241.0859, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 639 241.0859 1740
# <MS Adduct Search: TextType=form, Text=297.1122, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 640 297.1122 589
# <MS Adduct Search: TextType=form, Text=349.0626, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 641 349.0626 537
# <MS Adduct Search: TextType=form, Text=373.2374, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 642 373.2374 3366
# <MS Adduct Search: TextType=form, Text=375.1439, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 643 375.1439 3951
# <MS Adduct Search: TextType=form, Text=258.1085, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 646 258.1085 653
# <MS Adduct Search: TextType=form, Text=338.1459, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 647 338.1459 579
# <MS Adduct Search: TextType=form, Text=579.1709, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 648 579.1709 4852
# <MS Adduct Search: TextType=form, Text=362.1347, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 649 362.1347 1369
# <MS Adduct Search: TextType=form, Text=345.1333, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 650 345.1333 2097
# <MS Adduct Search: TextType=form, Text=359.1489, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 651 359.1489 4151
# <MS Adduct Search: TextType=form, Text=283.0965, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 652 283.0965 755
# <MS Adduct Search: TextType=form, Text=269.0809, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 653 269.0809 1142
# <MS Adduct Search: TextType=form, Text=281.1172, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 654 281.1172 236
# <MS Adduct Search: TextType=form, Text=282.1489, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 656 282.1489 268
# <MS Adduct Search: TextType=form, Text=198.0761, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 657 198.0761 665
# <MS Adduct Search: TextType=form, Text=585.2906, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 658 585.2906 1905
# <MS Adduct Search: TextType=form, Text=221.0476, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 659 221.0476 196
# <MS Adduct Search: TextType=form, Text=301.1071, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 660 301.1071 1610
# <MS Adduct Search: TextType=form, Text=345.0969, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 662 345.0969 1384
# <MS Adduct Search: TextType=form, Text=329.102, Parameters={'adducts': ['[M+]+', '[M+H]+', '[M+Na]+'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '+', 'models': []}>
# 663 329.102 1469

# %% [markdown]
# Now, negative

# %%
ms_params = {
    'adducts': ["[M-H]-", "[M+CH3COO]-"],
    'tolerance': 2,  # mDa
    'ppm': False,
    'logp': None,
    'halogens': True,
    'verbose': False,
    'charge': '-',
    'models': []
}

# %%
ids = mb_df.loc[mb_df.Mode == 'Negative'].index
masses = [str(val) for val in mb_df.loc[mb_df.Mode == 'Negative'].Mass.values]
len(masses)
# Out:
# 47

# %%
for cpd_id, mass in zip(ids, masses):
    hits_dict[cpd_id] = ms_adduct_search(db=db, core_db=core_db, keggdb=kegg_models_db, text=mass, text_type='form', ms_params=ms_params)
    print(cpd_id, mass, len(hits_dict[cpd_id]))
# Out:
# <MS Adduct Search: TextType=form, Text=450.0204, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 110 450.0204 244
# <MS Adduct Search: TextType=form, Text=145.06186, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 115 145.06186 290
# <MS Adduct Search: TextType=form, Text=203.0826, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 117 203.0826 591
# <MS Adduct Search: TextType=form, Text=118.05096, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 118 118.05096 232
# <MS Adduct Search: TextType=form, Text=132.03023, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 123 132.03023 153
# <MS Adduct Search: TextType=form, Text=300.2908, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 130 300.2908 159
# <MS Adduct Search: TextType=form, Text=450.05678, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 136 450.05678 338
# <MS Adduct Search: TextType=form, Text=406.2024, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 388 406.2024 622
# <MS Adduct Search: TextType=form, Text=141.0193, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 394 141.0193 461
# <MS Adduct Search: TextType=form, Text=343.0823, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 419 343.0823 3330
# <MS Adduct Search: TextType=form, Text=301.2173, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 420 301.2173 18811
# <MS Adduct Search: TextType=form, Text=367.1187, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 427 367.1187 1867
# <MS Adduct Search: TextType=form, Text=251.0713, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 432 251.0713 492
# <MS Adduct Search: TextType=form, Text=339.1714, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 439 339.1714 1258
# <MS Adduct Search: TextType=form, Text=301.1445, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 440 301.1445 2465
# <MS Adduct Search: TextType=form, Text=301.2173, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 441 301.2173 18811
# <MS Adduct Search: TextType=form, Text=345.1343, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 458 345.1343 7056
# <MS Adduct Search: TextType=form, Text=263.1289, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 459 263.1289 9955
# <MS Adduct Search: TextType=form, Text=325.0929, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 467 325.0929 1655
# <MS Adduct Search: TextType=form, Text=435.1296, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 471 435.1296 2021
# <MS Adduct Search: TextType=form, Text=423.1296, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 472 423.1296 2623
# <MS Adduct Search: TextType=form, Text=455.353, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 473 455.353 17086
# <MS Adduct Search: TextType=form, Text=289.0717, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 479 289.0717 2682
# <MS Adduct Search: TextType=form, Text=309.098, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 488 309.098 2031
# <MS Adduct Search: TextType=form, Text=179.035, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 493 179.035 657
# <MS Adduct Search: TextType=form, Text=471.348, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 514 471.348 14718
# <MS Adduct Search: TextType=form, Text=547.2661, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 530 547.2661 1050
# <MS Adduct Search: TextType=form, Text=193.0354, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 534 193.0354 713
# <MS Adduct Search: TextType=form, Text=391.2854, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 535 391.2854 8496
# <MS Adduct Search: TextType=form, Text=241.083, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 540 241.083 635
# <MS Adduct Search: TextType=form, Text=173.0455, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 544 173.0455 1360
# <MS Adduct Search: TextType=form, Text=285.098, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 546 285.098 1083
# <MS Adduct Search: TextType=form, Text=301.0717, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 547 301.0717 3253
# <MS Adduct Search: TextType=form, Text=375.2904, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 548 375.2904 2780
# <MS Adduct Search: TextType=form, Text=579.1719, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 552 579.1719 4201
# <MS Adduct Search: TextType=form, Text=277.2173, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 554 277.2173 3671
# <MS Adduct Search: TextType=form, Text=178.0509, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 558 178.0509 704
# <MS Adduct Search: TextType=form, Text=465.3216, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 559 465.3216 1808
# <MS Adduct Search: TextType=form, Text=123.0451, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 570 123.0451 139
# <MS Adduct Search: TextType=form, Text=205.0362, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 574 205.0362 1103
# <MS Adduct Search: TextType=form, Text=381.182, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 588 381.182 6327
# <MS Adduct Search: TextType=form, Text=304.9778, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 593 304.9778 12
# <MS Adduct Search: TextType=form, Text=225.0768, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 644 225.0768 1493
# <MS Adduct Search: TextType=form, Text=383.0136, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 645 383.0136 362
# <MS Adduct Search: TextType=form, Text=265.083, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 664 265.083 559
# <MS Adduct Search: TextType=form, Text=165.0921, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 665 165.0921 2293
# <MS Adduct Search: TextType=form, Text=299.0561, Parameters={'adducts': ['[M-H]-', '[M+CH3COO]-'], 'tolerance': 2, 'ppm': False, 'logp': None, 'halogens': True, 'verbose': False, 'charge': '-', 'models': []}>
# 666 299.0561 2451

# %% [markdown]
# ### Calculate Statistics from Search Output

# %%
n_annotated = 0
num_hits = []

for cpd_id, hits in hits_dict.items():
    if len(hits) > 0:
        n_annotated += 1
    num_hits.append(len(hits))
    print(cpd_id, len(hits))
# Out:
# 0 15
# 1 55
# 2 353
# 3 15
# 4 108
# 5 101
# 6 183
# 7 15
# 8 131
# 9 253
# 10 1142
# 11 86
# 12 5
# 13 298
# 14 24
# 15 715
# 16 72
# 17 79
# 18 127
# 19 865
# 20 911
# 21 64
# 22 31
# 23 67
# 24 664
# 25 57
# 26 684
# 27 858
# 28 187
# 29 96
# 30 102
# 31 684
# 32 362
# 33 692
# 34 575
# 35 318
# 36 234
# 37 528
# 38 495
# 39 450
# 40 1875
# 41 65
# 42 365
# 43 62
# 44 394
# 45 55
# 46 1510
# 47 594
# 48 394
# 49 179
# 50 269
# 51 273
# 52 124
# 53 460
# 54 99
# 55 546
# 56 160
# 57 250
# 58 38
# 59 87
# 60 103
# 61 498
# 62 133
# 64 971
# 65 2064
# 66 190
# 67 890
# 68 1628
# 69 511
# 70 857
# 71 581
# 72 557
# 73 2110
# 74 575
# 76 322
# 77 553
# 78 1166
# 79 993
# 80 635
# 81 67
# 82 1952
# 83 918
# 84 616
# 85 1893
# 86 1588
# 87 234
# 88 1026
# 89 429
# 90 222
# 91 1121
# 93 800
# 95 4852
# 96 396
# 97 522
# 98 1386
# 99 1575
# 100 573
# 102 3536
# 103 2048
# 104 935
# 105 666
# 106 138
# 107 340
# 108 138
# 109 675
# 111 36
# 112 581
# 113 520
# 114 358
# 116 743
# 119 514
# 122 112
# 124 675
# 125 68
# 126 742
# 127 3759
# 128 252
# 129 731
# 132 675
# 133 236
# 134 263
# 135 3759
# 137 497
# 138 236
# 139 75
# 140 3961
# 141 675
# 142 33
# 143 14
# 144 3
# 145 44
# 146 41
# 147 55
# 148 10
# 149 6
# 150 17
# 151 17
# 152 28
# 153 3
# 154 1602
# 155 21
# 156 17
# 157 41
# 158 33
# 159 54
# 160 26
# 161 90
# 162 71
# 163 83
# 164 247
# 165 271
# 166 86
# 167 187
# 168 480
# 169 175
# 170 1501
# 171 204
# 172 426
# 173 20
# 174 324
# 175 356
# 176 90
# 177 1023
# 178 111
# 179 24
# 180 297
# 181 229
# 182 87
# 183 79
# 184 140
# 185 684
# 186 831
# 187 41
# 188 228
# 189 121
# 190 28
# 191 46
# 192 67
# 193 826
# 194 858
# 195 536
# 196 81
# 197 357
# 198 108
# 199 96
# 200 414
# 201 23
# 202 104
# 203 23
# 204 105
# 205 146
# 206 70
# 207 193
# 208 576
# 209 185
# 210 177
# 211 239
# 212 60
# 213 870
# 214 304
# 215 880
# 216 294
# 217 310
# 218 242
# 219 328
# 220 274
# 221 124
# 223 193
# 224 516
# 225 465
# 226 2511
# 227 199
# 228 84
# 229 174
# 231 1047
# 232 95
# 233 34
# 234 534
# 235 28
# 236 470
# 237 157
# 238 84
# 239 735
# 240 570
# 241 283
# 243 384
# 244 106
# 245 123
# 246 1856
# 247 455
# 248 1763
# 249 42
# 250 7376
# 251 429
# 252 237
# 253 116
# 254 474
# 255 264
# 256 584
# 257 168
# 258 276
# 259 104
# 260 99
# 261 111
# 262 58
# 263 705
# 264 872
# 265 2373
# 266 95
# 267 167
# 268 10
# 269 176
# 270 4
# 271 4230
# 272 33
# 273 5
# 274 32
# 275 144
# 276 417
# 277 41
# 278 26
# 279 1149
# 280 2
# 281 2301
# 282 247
# 283 248
# 284 290
# 285 1359
# 286 2010
# 287 723
# 288 164
# 289 848
# 290 583
# 291 857
# 292 1164
# 293 662
# 294 372
# 295 206
# 296 785
# 297 223
# 298 7514
# 299 1015
# 300 2251
# 301 782
# 302 594
# 303 2275
# 304 282
# 305 214
# 306 451
# 307 2517
# 308 1030
# 309 1329
# 310 2993
# 311 362
# 313 107
# 314 23
# 315 1786
# 316 301
# 317 1892
# 318 1041
# 319 289
# 320 1458
# 321 1375
# 322 7258
# 323 495
# 324 451
# 325 723
# 326 126
# 327 193
# 328 1543
# 329 585
# 330 738
# 331 264
# 332 1802
# 333 1694
# 334 2071
# 335 83
# 336 429
# 337 527
# 338 109
# 339 174
# 340 1697
# 341 2753
# 342 1923
# 343 4191
# 344 97
# 345 75
# 346 300
# 347 5421
# 348 1406
# 349 1813
# 350 81
# 351 81
# 352 1329
# 354 121
# 355 324
# 356 1276
# 357 1066
# 358 1537
# 359 3356
# 360 299
# 361 97
# 362 349
# 363 2784
# 364 72
# 365 348
# 366 176
# 367 8902
# 368 2926
# 369 1733
# 370 267
# 371 164
# 372 798
# 373 774
# 374 330
# 375 113
# 376 64
# 377 155
# 378 397
# 380 875
# 381 423
# 382 524
# 383 263
# 384 1773
# 385 723
# 387 2140
# 389 213
# 390 1881
# 391 1628
# 392 456
# 393 1423
# 395 29
# 396 243
# 398 3177
# 399 1575
# 400 1970
# 401 458
# 403 1836
# 404 147
# 405 521
# 406 3365
# 407 302
# 408 2646
# 409 1142
# 410 2005
# 411 670
# 412 403
# 414 496
# 415 1121
# 416 1692
# 417 1908
# 418 522
# 421 585
# 422 1575
# 423 2492
# 424 81
# 425 437
# 426 211
# 428 2064
# 429 1692
# 430 1142
# 431 220
# 433 272
# 434 3940
# 435 841
# 436 1098
# 437 1627
# 438 28
# 442 510
# 443 2399
# 444 1341
# 445 1694
# 446 1549
# 447 521
# 448 2064
# 449 727
# 450 2234
# 451 20
# 452 918
# 453 3940
# 454 1590
# 455 4286
# 457 3926
# 460 3007
# 461 1549
# 462 181
# 463 5016
# 464 2942
# 465 838
# 466 879
# 468 284
# 469 3940
# 470 1844
# 474 1901
# 475 553
# 476 1071
# 477 1417
# 478 749
# 480 1685
# 481 918
# 483 236
# 484 2662
# 485 981
# 486 690
# 487 789
# 489 550
# 490 745
# 491 1026
# 492 6828
# 494 511
# 495 351
# 496 370
# 497 662
# 498 1142
# 499 1835
# 500 550
# 501 1718
# 502 565
# 503 466
# 504 184
# 505 1027
# 506 747
# 507 539
# 508 365
# 509 570
# 510 437
# 511 2110
# 512 1142
# 513 1053
# 515 1945
# 516 1147
# 518 1335
# 519 1970
# 520 2407
# 521 3847
# 522 516
# 523 742
# 524 3941
# 525 215
# 526 1423
# 527 384
# 528 1651
# 531 124
# 532 396
# 533 9215
# 536 736
# 537 2044
# 538 716
# 539 798
# 541 256
# 542 151
# 543 1692
# 545 209
# 549 576
# 550 171
# 551 1692
# 555 152
# 556 659
# 557 742
# 560 638
# 561 881
# 562 563
# 563 1083
# 564 410
# 565 1692
# 566 1442
# 567 635
# 568 816
# 569 314
# 571 127
# 572 2969
# 573 1740
# 575 1044
# 577 3828
# 578 123
# 579 386
# 580 1720
# 581 900
# 582 420
# 583 303
# 584 1626
# 585 256
# 586 162
# 587 1208
# 589 653
# 590 98
# 591 433
# 592 254
# 594 436
# 595 483
# 596 236
# 597 17
# 598 239
# 599 1970
# 600 1692
# 601 214
# 602 659
# 603 1047
# 604 1142
# 605 892
# 606 329
# 607 789
# 608 83
# 609 43
# 610 546
# 612 281
# 613 1184
# 614 572
# 615 278
# 616 1208
# 617 142
# 618 245
# 619 3365
# 622 1833
# 623 2121
# 624 802
# 625 511
# 628 47
# 629 326
# 630 222
# 631 2383
# 633 1849
# 634 1591
# 636 2341
# 637 1208
# 638 596
# 639 1740
# 640 589
# 641 537
# 642 3366
# 643 3951
# 646 653
# 647 579
# 648 4852
# 649 1369
# 650 2097
# 651 4151
# 652 755
# 653 1142
# 654 236
# 656 268
# 657 665
# 658 1905
# 659 196
# 660 1610
# 662 1384
# 663 1469
# 110 244
# 115 290
# 117 591
# 118 232
# 123 153
# 130 159
# 136 338
# 388 622
# 394 461
# 419 3330
# 420 18811
# 427 1867
# 432 492
# 439 1258
# 440 2465
# 441 18811
# 458 7056
# 459 9955
# 467 1655
# 471 2021
# 472 2623
# 473 17086
# 479 2682
# 488 2031
# 493 657
# 514 14718
# 530 1050
# 534 713
# 535 8496
# 540 635
# 544 1360
# 546 1083
# 547 3253
# 548 2780
# 552 4201
# 554 3671
# 558 704
# 559 1808
# 570 139
# 574 1103
# 588 6327
# 593 12
# 644 1493
# 645 362
# 664 559
# 665 2293
# 666 2451

# %%
n_annotated
# Out:
# 634

# %%
n_annotated / 634
# Out:
# 1.0

# %%
np.median(num_hits)
# Out:
# 536.5

# %%
np.mean(num_hits)
# Out:
# 1082.4069400630915

# %% [markdown]
# ### Check for Correct Annotation with InChI

# %%
n_correct_annotation = 0
for cpd_id, hits in hits_dict.items():
    inchi = mb_df.at[cpd_id, 'InChI_Key']
    inchi_prefix = inchi.split('-')[0]
    for hit in hits:
        hit_inchi = hit['Inchikey']
        hit_inchi_prefix = hit_inchi.split('-')[0]
        if hit_inchi_prefix == inchi_prefix:
            n_correct_annotation += 1
            break

# %%
n_correct_annotation
# Out:
# 461

# %%
n_correct_annotation / 634
# Out:
# 0.7271293375394322

# %%
len(core_db.compounds.distinct("Formula", {"MINES": "kegg_lte600_500mcy_2_1_0"}))
# Out:
# 220934
